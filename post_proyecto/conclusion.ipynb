# %% [markdown]
# # Sprint 18. Proyecto Final
#
# ## Conclusión

# %% [markdown]
# ### **¡Lo conseguiste! ¡Felicidades!**
#
# Si el líder del equipo ha aceptado tu proyecto final, solo puede significar una cosa: has adquirido una base sólida en data science y dominas las habilidades esenciales requeridas de un profesional de datos.
#
# Escribes código en Python y SQL, formulas y pruebas hipótesis estadísticas, trabajas con datos en varios formatos y comprendes los fundamentos de estadística, álgebra lineal e incluso modelos de aprendizaje automático de todo tipo, desde la regresión hasta las redes neuronales. Y pensar que todo comenzó con la impresión de una sola cadena...
#
# **Tu primer programa... otra vez**
#
# Escribe el siguiente código:

# %%
print('¡Hola, mundo!')
# Out:
# ¡Hola, mundo!

# %% [markdown]
# Has llegado al final del programa Data Scientist, pero esto es más un comienzo que un final. Ahora puedes comenzar una nueva carrera o aplicar lo que has aprendido en tu puesto actual.
#
# **¿Hora de decir adiós?**
#
# No exactamente. Pronto recibirás una invitación para unirte a una comunidad de graduados de TripleTen donde podrás contactarnos al igual que a otros estudiantes.
#
# Siempre tendrás acceso a la plataforma (teoría de la lección, tareas, proyectos) y a Notion. Cerraremos tus canales de Slack, pero tendrás un archivo de los mensajes enviados allí en formato CSV.
#
# Debes sentir gran orgullo por ti, nosotros definitivamente lo sentimos.
#
# ¡Nos vemos en la ceremonia de graduación!
